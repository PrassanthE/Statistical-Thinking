# %% [markdown]
# ###### Generating a Random Number

# %%
import numpy as np
np.random.rand()     #To generate a pseudo random number
# Out:
# 0.1523877833441024

# %%
#To set a seed - 
np.random.seed(3)
np.random.rand()
# Out:
# 0.5507979025745755

# %%
#Simulating a coin toss

import numpy as np
np.random.seed(3)
coin = np.random.randint(0,2)    #To randomly generate 0 or 1
print(coin)

print('heads') if coin == 1 else print('tails')
# Out:
# 0
# tails

# %%
# import numpy as np
# tails = [0]
# t = []

# for x in range(10):
#     print(x)
#     coin = np.random.randint(0,2)
#     print(coin)
#     print(tails)
#     tails.append(tails[x] + coin)

# %%
# Random Walk - stochastic or random process, that describes a path that consists of a succession of random steps

# Using the dice.
# If dice is 1 or 2, then one step down.
# if dice is 3, 4 or 5, then one step up.
# Else, dice is throw again. The number of eyes is the number of steps you go up.


random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)

# Show the plot
plt.show()

# %%
#Looping it over

all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks)

# Transpose np_aw: np_aw_t
np_aw_t = np_aw.T

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
#Adding Clumsiness -- there is a 1 % chance that while walking person gets clumy anf falls down


all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() < 0.01 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()
